# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests 



page = requests.get("https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c")
soup = BeautifulSoup(page.content,'html.parser')
#print(soup)
#print(page)


# Getting list of days

days_list = soup.find_all('div', class_ = 'DetailsSummary--DetailsSummary--2HluQ DetailsSummary--fadeOnOpen--vFCc_')

list_day = []

for days in days_list:
    day_time = days.h2.text.split()[0]
    list_day.append(day_time)

ld1 = list_day[1:11]
#print(len(ld1))

# Getting the descriptions

des = soup.find_all('div', class_ ='DaypartDetails--Content--hJ52O DaypartDetails--contentGrid--1SWty')

sd = []

for i in des:
    s_d = i.p.text
    sd.append(s_d)

sd1 = sd[1:11]
#print(len(sd1))

# Getting temperatures

temp = soup.find_all('div', class_ = 'DailyContent--ConditionSummary--1X5kT')

t = []

for i in temp:
    t_ = i.span.text
    t.append(t_)
#print((t))

h = t[0::2]
#print(h)

l = t[1::2]
#print(l)

def sti(n):  #converting string to int

    for i in range(len(n)):
        n[i] = int(n[i][0:2])

    return n

hn = sti(h)

#print(hn)

ln = sti(l)

def ftc(newlist): # converting Farenheit to Celcius
    newtemp = []

    for i in newlist:
        new_temp = round((i - 32)*(5/9),2)
        newtemp.append(new_temp)

    return newtemp
    

hc = ftc(hn)
#print(hc)

lc = ftc(ln)
#print(lc)


hc1 = hc[1:11]
#print(len(lc1))

lc1 = lc[0:10]
#print((hc1))

# generating the dataframe

df = pd.DataFrame({ 'Day': ld1,
                            'Description': sd1,
                            'Day-Temp °C': hc1,
                            'Night-Temp °C': lc1})

df['Date'] = pd.date_range(start='02/08/2022', periods=len(df), freq='D')

df[['Day','Date', 'Day-Temp °C', 'Night-Temp °C', 'Description']]
# Out:
# [16.67, 19.44, 20.56, 18.33, 18.89, 17.78, 14.44, 15.56, 17.22, 15.56, 16.11, 16.11, 15.0, 15.0, 15.0]
# [7.78, 10.0, 7.78, 7.22, 7.22, 7.22, 6.11, 7.22, 6.67, 6.11, 6.11, 5.56, 5.56, 5.56, 5.0]
#    Day       Date  Day-Temp °C  Night-Temp °C  \
# 0  Wed 2022-02-08        19.44           7.78
# 1  Thu 2022-02-09        20.56          10.00
# 2  Fri 2022-02-10        18.33           7.78
# 3  Sat 2022-02-11        18.89           7.22
# 4  Sun 2022-02-12        17.78           7.22
# 5  Mon 2022-02-13        14.44           7.22
# 6  Tue 2022-02-14        15.56           6.11
# 7  Wed 2022-02-15        17.22           7.22
# 8  Thu 2022-02-16        15.56           6.67
# 9  Fri 2022-02-17        16.11           6.11
#
#                                          Description
# 0          Sunny. High 67F. Winds NE at 5 to 10 mph.
# 1  A mainly sunny sky. High 69F. Winds NE at 10 t...
# 2  Mainly sunny. High around 65F. Winds NNE at 5 ...
# 3  Sunny, along with a few afternoon clouds. High...
# 4  Partly cloudy. High 64F. Winds NNW at 5 to 10 ...
# 5  Sunshine along with some cloudy intervals. Hig...
# 6  Mainly sunny. High around 60F. Winds NNW at 10...
# 7    Sunny skies. High 63F. Winds N at 10 to 15 mph.
# 8  Intervals of clouds and sunshine. High around ...
# 9  Partly cloudy skies. High 61F. Winds NNW at 5 ...
